# %%
# !pwd
# !ls
# Out:
# /content
# Dataset.zip  drive  sample_data

# %%
# !ls /content/drive/MyDrive/Sample_data/
# !cp /content/drive/MyDrive/Sample_data/* .
# Out:
# Dataset.zip

# %%
# !ls
# Out:
# Dataset.zip  drive  sample_data

# %%
import zipfile
import pandas as pd




zip_path='/content/Dataset.zip'

# %%
file_to_extract = 'Dataset/Train.csv'
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    with zip_ref.open(file_to_extract) as csv_file:
      train= pd.read_csv(csv_file)
train.head(5)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
file_to_extract = 'Dataset/Test.csv'
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    with zip_ref.open(file_to_extract) as csv_file:
      test= pd.read_csv(csv_file)
file_to_extract = 'Dataset/sample_submission.csv'
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    with zip_ref.open(file_to_extract) as csv_file:
      submission= pd.read_csv(csv_file)
submission.head(5)
# Out:
#    price
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    file_list = zip_ref.namelist()
    for x in file_list:
        print(x)
# Out:
# Dataset/sample_submission.csv
# Dataset/Test.csv
# Dataset/Train.csv

# %%
#submission.columns
#train.columns
test.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony'],
#       dtype='object')

# %%
train.shape
# Out:
# (13320, 9)

# %%
train.head(5)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
train.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
((train.isna().sum()/train.shape[0])*100).sort_values(ascending=False)
# Out:
# society         41.306306
# balcony          4.572072
# bath             0.548048
# size             0.120120
# location         0.007508
# area_type        0.000000
# availability     0.000000
# total_sqft       0.000000
# price            0.000000
# dtype: float64

# %%
train.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
train.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
train['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
for i in train.columns:
  print(f"column: {i}: no_of_unique_values: {train[i].nunique()} : {train[i].unique()}")
# Out:
# column: area_type: no_of_unique_values: 4 : ['Super built-up  Area' 'Plot  Area' 'Built-up  Area' 'Carpet  Area']
# column: availability: no_of_unique_values: 81 : ['19-Dec' 'Ready To Move' '18-May' '18-Feb' '18-Nov' '20-Dec' '17-Oct'
#  '21-Dec' '19-Sep' '20-Sep' '18-Mar' '20-Feb' '18-Apr' '20-Aug' '18-Oct'
#  '19-Mar' '17-Sep' '18-Dec' '17-Aug' '19-Apr' '18-Jun' '22-Dec' '22-Jan'
#  '18-Aug' '19-Jan' '17-Jul' '18-Jul' '21-Jun' '20-May' '19-Aug' '18-Sep'
#  '17-May' '17-Jun' '21-May' '18-Jan' '20-Mar' '17-Dec' '16-Mar' '19-Jun'
#  '22-Jun' '19-Jul' '21-Feb' 'Immediate Possession' '19-May' '17-Nov'
#  '20-Oct' '20-Jun' '19-Feb' '21-Oct' '21-Jan' '17-Mar' '17-Apr' '22-May'
#  '19-Oct' '21-Jul' '21-Nov' '21-Mar' '16-Dec' '22-Mar' '20-Jan' '21-Sep'
#  '21-Aug' '14-Nov' '19-Nov' '15-Nov' '16-Jul' '15-Jun' '17-Feb' '20-Nov'
#  '20-Jul' '16-Sep' '15-Oct' '15-Dec' '16-Oct' '22-Nov' '15-Aug' '17-Jan'
#  '16-Nov' '20-Apr' '16-Jan' '14-Jul']
# ...

# %%
train_org = train.copy()
test_org = test.copy()

# %%
train_1 = train.dropna()

# %%
train.shape
# Out:
# (13320, 9)

# %%
train_2 = train_1.drop_duplicates()

# %%
from sklearn.preprocessing import OrdinalEncoder,StandardScaler

cat_cols = train_2.select_dtypes(include='object').columns
num_cols = train_2.select_dtypes(exclude='object').columns
cat_cols,num_cols
# Out:
# (Index([], dtype='object'),
#  Index(['area_type', 'availability', 'location', 'size', 'society',
#         'total_sqft', 'bath', 'balcony', 'price'],
#        dtype='object'))

# %%
train3=train.drop(columns=['price'])
train4=train['price']
encoder=OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
train3[cat_cols]=encoder.fit_transform(train3[cat_cols])

# %%
train3.head(10)
# Out:
#    area_type  availability  location  size  society  total_sqft  bath  balcony
# 0        3.0          40.0     419.0  13.0    464.0        70.0   2.0      1.0
# 1        2.0          80.0     317.0  19.0   2439.0      1288.0   5.0      3.0
# 2        0.0          80.0    1179.0  16.0      NaN       514.0   2.0      3.0
# 3        3.0          80.0     757.0  16.0   2186.0       602.0   3.0      1.0
# 4        3.0          80.0     716.0  13.0      NaN       239.0   2.0      1.0
# 5        3.0          80.0    1252.0  13.0    607.0       205.0   2.0      1.0
# 6        3.0          34.0     895.0  18.0    939.0      1319.0   4.0      NaN
# 7        3.0          80.0     976.0  18.0    360.0      1466.0   4.0      NaN
# 8        3.0          80.0     799.0  16.0      NaN       369.0   3.0      1.0
# 9        2.0          80.0     434.0  24.0      NaN        31.0   6.0      NaN

# %%
train.head(10)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6  Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8  Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9            Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# ...

# %%
tarin5=train3.dropna()
scaler=StandardScaler()
scaled_train=scaler.fit_transform(tarin5)
pd.DataFrame(scaled_train).head(10)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.470339 -1.567092 -0.736992 -0.293195 -1.215699 -1.090808 -0.520252
# 1 -0.446131  0.525882 -1.019877  1.350013  1.465773  0.939511  2.884703
# 2  0.470339  0.525882  0.200413  0.528409  1.122273 -0.204002  0.614733
# 3  0.470339  0.525882  1.573239 -0.293195 -1.021547 -0.865772 -0.520252
# 4 -0.446131  0.525882  1.573239  1.350013  0.360599  1.016189  2.884703
# 5  0.470339  0.525882 -1.699357 -0.293195  0.990575 -1.202492 -0.520252
# 6 -0.446131  0.525882  0.979735  0.802277  1.074753  0.707808  0.614733
# 7  0.470339  0.525882  0.422284 -0.293195  0.329372 -0.857438 -0.520252
# 8  0.470339  0.525882 -1.155773  0.528409  0.302218 -0.849103  0.614733
# 9  0.470339  0.525882  0.796691  0.528409 -0.751363 -0.175664  0.614733
#
#           7
# 0 -0.807533
# 1  1.756324
# 2 -0.807533
# 3 -0.807533
# 4  1.756324
# 5 -0.807533
# 6  0.474396
# 7  0.474396
# 8  0.474396
# 9  1.756324

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_train, tarin5, test_size=0.2, random_state=42)

# %%
X_train, X_test, y_train, y_test
# Out:
# (array([[ 0.47033876, -2.19498424, -0.41250537, ..., -0.88077468,
#          -0.52025189, -0.80753266],
#         [ 0.47033876, -2.19498424, -0.47629326, ...,  0.41609536,
#           0.61473303,  0.47439551],
#         [ 0.47033876,  0.52588208, -0.47629326, ..., -1.12081232,
#          -0.52025189, -0.80753266],
#         ...,
#         [ 0.47033876,  0.52588208, -1.05038429, ..., -0.97245572,
#          -0.52025189, -0.80753266],
#         [ 0.47033876,  0.52588208,  1.59819992, ...,  1.81298107,
#          -1.65523682, -0.80753266],
#         [ 0.47033876,  0.52588208,  1.57323944, ..., -0.65907325,
#          -0.52025189, -0.80753266]]),
#  array([[-2.27907064,  0.52588208,  0.40841707, ..., -0.17566411,
#          -0.52025189,  1.75632369],
#         [ 0.47033876,  0.52588208,  0.79669119, ..., -0.61906697,
#          -0.52025189, -0.80753266],
#         [ 0.47033876, -1.61941637, -1.2556149 , ...,  0.80782345,
#           4.0196878 , -2.08946084],
#         ...,
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
val_pred = knn.predict(X_test)

# %%
from  sklearn.metrics import r2_score, root_mean_squared_error
r2_score(y_test,val_pred)
# Out:
# 0.9771220620438292

# %%
root_mean_squared_error(y_test,val_pred)
# Out:
# 38.347085282106136
