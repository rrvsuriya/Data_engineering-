# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/Laxminarayen/Inceptez-batch-25-Classwork/refs/heads/main/Python-Class12-DescriptiveStatistics-Pandas/US_Baby_Names_right.csv).

# %%
df1 = pd.read_csv("/content/sample_data/US_Baby_Names_right.csv", header=0, delimiter=",")
df1.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016395 entries, 0 to 1016394
# Data columns (total 7 columns):
# Unnamed: 0    1016395 non-null int64
# Id            1016395 non-null int64
# Name          1016395 non-null object
# Year          1016395 non-null int64
# Gender        1016395 non-null object
# State         1016395 non-null object
# Count         1016395 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 54.3+ MB

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
df1.drop(['Unnamed: 0', 'Id'], axis=1)
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
df2=df1.drop(['Unnamed: 0', 'Id'], axis=1)

# %% [markdown]
# ### Step 6. Are there more male or female names in the dataset?

# %%
df2['Gender'].value_counts()
# Out:
# Gender
# F    558846
# M    457549
# Name: count, dtype: int64

# %%
# Out:
# Name
# Riley        1112
# Avery        1080
# Jordan       1073
# Peyton       1064
# Hayden       1049
#              ...
# Anaka           1
# Montanna        1
# Thaddaeus       1
# Miroslav        1
# Ackley          1
# Name: count, Length: 17632, dtype: int64

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
df2['Name'].value_counts().sort_values(ascending=False)
# Out:
# Name
# Riley        1112
# Avery        1080
# Jordan       1073
# Peyton       1064
# Hayden       1049
#              ...
# Magdala         1
# Sherlynn        1
# Nephtalie       1
# Catriona        1
# Claudine        1
# Name: count, Length: 17632, dtype: int64

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
# Out:
# np.int64(17632)

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
# Out:
# 'Jacob'

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
# Out:
# 2578

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
df1['Name'].value_counts().median()
# Out:
# 8.0

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
df1['Name'].value_counts().std()
# Out:
# 122.02996350814088

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
df1['Name'].value_counts().describe()
# Out:
# count    17632.000000
# mean        57.644907
# std        122.029964
# min          1.000000
# 25%          2.000000
# 50%          8.000000
# 75%         39.000000
# max       1112.000000
# Name: count, dtype: float64

# %%
name_counts=df1['Name'].value_counts()
sns.histplot(name_counts, bins=100, kde=True, log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
name_counts = df1['Name'].value_counts().reset_index()
name_counts.columns = ['Name', 'Count']

# 2. Plot with seaborn
plt.figure(figsize=(12,6))
sns.barplot(x='Name', y='Count', data=name_counts)
# Out:
# <Axes: xlabel='Name', ylabel='Count'>
